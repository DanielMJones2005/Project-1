# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import requests
from pprint import pprint

# Import API key
from api_keys import api_key

# %%
url = "http://api.eia.gov/category/?"
query_url=f"{url}api_key={api_key}&series_id=TOTAL.CLACBUS.A"

response=requests.get(query_url)
print(response.status_code)
# Out:
# 200

# %%
url = "http://api.eia.gov/category/?"
query_url=f"{url}api_key={api_key}&category_id=711253"
print(query_url)

eia_json = requests.get(query_url).json()

pprint(eia_json)
# Out:
# http://api.eia.gov/category/?api_key=d7c7d5a92f23e68e5710fc5cfbd273dc&category_id=711253
# {'category': {'category_id': '711253',
#               'childcategories': [],
#               'childseries': [{'f': 'A',
#                                'name': 'Coal Consumed by the Transportation '
#                                        'Sector, Annual',
#                                'series_id': 'TOTAL.CLACBUS.A',
#                                'units': 'Trillion Btu',
#                                'updated': '25-MAR-19 02.55.14 PM'},
#                               {'f': 'M',
#                                'name': 'Coal Consumed by the Transportation '
#                                        'Sector, Monthly',
#                                'series_id': 'TOTAL.CLACBUS.M',
#                                'units': 'Trillion Btu',
#                                'updated': '24-JUN-19 11.59.37 AM'},
#                               {'f': 'A',
#                                'name': 'Electricity Retail Sales to the '
#                                        'Transportation Sector, Annual',
#                                'series_id': 'TOTAL.ESACBUS.A',
#                                'units': 'Trillion Btu',
#                                'updated': '25-MAR-19 02.55.14 PM'},
#                               {'f': 'M',
#                                'name': 'Electricity Retail Sales to the '
#                                        'Transportation Sector, Monthly',
#                                'series_id': 'TOTAL.ESACBUS.M',
#                                'units': 'Trillion Btu',
#                                'updated': '24-JUN-19 11.59.37 AM'},
#                               {'f': 'A',
#                                'name': 'Total Fossil Fuels Consumed by the '
#                                        'Transportation Sector, Annual',
#                                'series_id': 'TOTAL.FFACBUS.A',
#                                'units': 'Trillion Btu',
#                                'updated': '23-MAY-19 03.52.44 PM'},
#                               {'f': 'M',
#                                'name': 'Total Fossil Fuels Consumed by the '
#                                        'Transportation Sector, Monthly',
#                                'series_id': 'TOTAL.FFACBUS.M',
#                                'units': 'Trillion Btu',
#                                'updated': '24-JUN-19 11.59.37 AM'},
#                               {'f': 'A',
#                                'name': 'Transportation Sector Electrical '
#                                        'System Energy Losses, Annual',
#                                'series_id': 'TOTAL.LOACBUS.A',
#                                'units': 'Trillion Btu',
#                                'updated': '25-APR-19 08.13.40 AM'},
#                               {'f': 'M',
#                                'name': 'Transportation Sector Electrical '
#                                        'System Energy Losses, Monthly',
#                                'series_id': 'TOTAL.LOACBUS.M',
#                                'units': 'Trillion Btu',
#                                'updated': '24-JUN-19 11.59.37 AM'},
#                               {'f': 'A',
#                                'name': 'Natural Gas Consumed by the '
#                                        'Transportation Sector (Excluding '
#                                        'Supplemental Gaseous Fuels), Annual',
#                                'series_id': 'TOTAL.NGACBUS.A',
#                                'units': 'Trillion Btu',
#                                'updated': '23-MAY-19 03.52.44 PM'},
#                               {'f': 'M',
#                                'name': 'Natural Gas Consumed by the '
#                                        'Transportation Sector (Excluding '
#                                        'Supplemental Gaseous Fuels), Monthly',
#                                'series_id': 'TOTAL.NGACBUS.M',
#                                'units': 'Trillion Btu',
#                                'updated': '24-JUN-19 11.59.37 AM'},
#                               {'f': 'A',
#                                'name': 'Petroleum Consumed by the '
#                                        'Transportation Sector (Excluding '
#                                        'Biofuels), Annual',
#                                'series_id': 'TOTAL.PMACBUS.A',
#                                'units': 'Trillion Btu',
#                                'updated': '23-MAY-19 03.52.44 PM'},
#                               {'f': 'M',
#                                'name': 'Petroleum Consumed by the '
#                                        'Transportation Sector (Excluding '
#                                        'Biofuels), Monthly',
#                                'series_id': 'TOTAL.PMACBUS.M',
#                                'units': 'Trillion Btu',
#                                'updated': '24-JUN-19 11.59.37 AM'},
#                               {'f': 'A',
#                                'name': 'Total Biomass Energy Consumed by the '
#                                        'Transportation Sector, Annual',
#                                'series_id': 'TOTAL.REACBUS.A',
#                                'units': 'Trillion Btu',
#                                'updated': '25-MAR-19 02.55.14 PM'},
#                               {'f': 'M',
#                                'name': 'Total Biomass Energy Consumed by the '
#                                        'Transportation Sector, Monthly',
#                                'series_id': 'TOTAL.REACBUS.M',
#                                'units': 'Trillion Btu',
#                                'updated': '24-JUN-19 11.59.37 AM'},
#                               {'f': 'A',
#                                'name': 'Total Energy Consumed by the '
#                                        'Transportation Sector, Annual',
#                                'series_id': 'TOTAL.TEACBUS.A',
#                                'units': 'Trillion Btu',
#                                'updated': '23-MAY-19 03.52.44 PM'},
#                               {'f': 'M',
#                                'name': 'Total Energy Consumed by the '
#                                        'Transportation Sector, Monthly',
#                                'series_id': 'TOTAL.TEACBUS.M',
#                                'units': 'Trillion Btu',
#                                'updated': '24-JUN-19 11.59.37 AM'},
#                               {'f': 'A',
#                                'name': 'Total Primary Energy Consumed by the '
#                                        'Transportation Sector, Annual',
#                                'series_id': 'TOTAL.TXACBUS.A',
#                                'units': 'Trillion Btu',
#                                'updated': '23-MAY-19 03.52.44 PM'},
#                               {'f': 'M',
#                                'name': 'Total Primary Energy Consumed by the '
#                                        'Transportation Sector, Monthly',
#                                'series_id': 'TOTAL.TXACBUS.M',
#                                'units': 'Trillion Btu',
#                                'updated': '24-JUN-19 11.59.37 AM'}],
#               'name': 'Transportation Sector Energy Consumption',
#               'notes': '',
#               'parent_category_id': '711226'},
#  'request': {'category_id': 711253, 'command': 'category'}}

# %%
url = "http://api.eia.gov/series/?api_key="
api_code1="&series_id=TOTAL."
api_code2=".A"
category=["TEACBUS"]

#"CLACBUS","ESACBUS","FFACBUS","LOACBUS","NGACBUS","PMACBUS","REACBUS","TXACBUS"
#query_url=f"{url}{api_key}&series_id=TOTAL.BMCCBUS.A"
#print(query_url)

#eia_json = requests.get(query_url).json()

#pprint(eia_json)

# %%
start = []
end = []
f = []
name = []
sector = []
series_id = []
units = []
updated = []
year = []
value = []
data = []
count_cat = 0

for cat in category:
        query_url = url + api_key + api_code1 + cat + api_code2
        count_cat = count_cat + 1
        print("Processing Record " + str(count_cat) + " | " + cat)

        consumption_response = requests.get(query_url).json()
        
       
        data.append(consumption_response["series"][0]["data"])
        ln = (len(data[0]))

        for i in range(0,ln):
            start.append(consumption_response["series"][0]["start"])
            end.append(consumption_response["series"][0]["end"])
            f.append(consumption_response["series"][0]["f"])
            name.append(consumption_response["series"][0]["name"])
            sector.append(consumption_response["series"][0]["name"].split(" ")[5])
            series_id.append(consumption_response["series"][0]["series_id"])
            units.append(consumption_response["series"][0]["units"])
            updated.append(consumption_response["series"][0]["updated"])
            year.append(consumption_response["series"][0]["data"][i][0])
            value.append(consumption_response["series"][0]["data"][i][1])
print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Processing Record 1 | TEACBUS
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
consumption_trans_df = pd.DataFrame({
   "start":start,
   "end":end,
   "name": name,
   "sector": sector,
   "series_id": series_id,
   "units": units,
   "updated": updated,
   "year": year,
   "value": value
})
consumption_trans_df
# Out:
#    start   end                                               name  \
# 0   1949  2018  Total Energy Consumed by the Transportation Se...
# 1   1949  2018  Total Energy Consumed by the Transportation Se...
# 2   1949  2018  Total Energy Consumed by the Transportation Se...
# 3   1949  2018  Total Energy Consumed by the Transportation Se...
# 4   1949  2018  Total Energy Consumed by the Transportation Se...
# 5   1949  2018  Total Energy Consumed by the Transportation Se...
# 6   1949  2018  Total Energy Consumed by the Transportation Se...
# 7   1949  2018  Total Energy Consumed by the Transportation Se...
# 8   1949  2018  Total Energy Consumed by the Transportation Se...
# 9   1949  2018  Total Energy Consumed by the Transportation Se...
# 10  1949  2018  Total Energy Consumed by the Transportation Se...
# 11  1949  2018  Total Energy Consumed by the Transportation Se...
# 12  1949  2018  Total Energy Consumed by the Transportation Se...
# 13  1949  2018  Total Energy Consumed by the Transportation Se...
# 14  1949  2018  Total Energy Consumed by the Transportation Se...
# 15  1949  2018  Total Energy Consumed by the Transportation Se...
# 16  1949  2018  Total Energy Consumed by the Transportation Se...
# 17  1949  2018  Total Energy Consumed by the Transportation Se...
# 18  1949  2018  Total Energy Consumed by the Transportation Se...
# 19  1949  2018  Total Energy Consumed by the Transportation Se...
# 20  1949  2018  Total Energy Consumed by the Transportation Se...
# 21  1949  2018  Total Energy Consumed by the Transportation Se...
# 22  1949  2018  Total Energy Consumed by the Transportation Se...
# 23  1949  2018  Total Energy Consumed by the Transportation Se...
# 24  1949  2018  Total Energy Consumed by the Transportation Se...
# 25  1949  2018  Total Energy Consumed by the Transportation Se...
# 26  1949  2018  Total Energy Consumed by the Transportation Se...
# 27  1949  2018  Total Energy Consumed by the Transportation Se...
# 28  1949  2018  Total Energy Consumed by the Transportation Se...
# 29  1949  2018  Total Energy Consumed by the Transportation Se...
# ..   ...   ...                                                ...
# 40  1949  2018  Total Energy Consumed by the Transportation Se...
# 41  1949  2018  Total Energy Consumed by the Transportation Se...
# 42  1949  2018  Total Energy Consumed by the Transportation Se...
# 43  1949  2018  Total Energy Consumed by the Transportation Se...
# 44  1949  2018  Total Energy Consumed by the Transportation Se...
# 45  1949  2018  Total Energy Consumed by the Transportation Se...
# 46  1949  2018  Total Energy Consumed by the Transportation Se...
# 47  1949  2018  Total Energy Consumed by the Transportation Se...
# 48  1949  2018  Total Energy Consumed by the Transportation Se...
# 49  1949  2018  Total Energy Consumed by the Transportation Se...
# 50  1949  2018  Total Energy Consumed by the Transportation Se...
# 51  1949  2018  Total Energy Consumed by the Transportation Se...
# 52  1949  2018  Total Energy Consumed by the Transportation Se...
# 53  1949  2018  Total Energy Consumed by the Transportation Se...
# 54  1949  2018  Total Energy Consumed by the Transportation Se...
# 55  1949  2018  Total Energy Consumed by the Transportation Se...
# 56  1949  2018  Total Energy Consumed by the Transportation Se...
# 57  1949  2018  Total Energy Consumed by the Transportation Se...
# 58  1949  2018  Total Energy Consumed by the Transportation Se...
# 59  1949  2018  Total Energy Consumed by the Transportation Se...
# 60  1949  2018  Total Energy Consumed by the Transportation Se...
# 61  1949  2018  Total Energy Consumed by the Transportation Se...
# 62  1949  2018  Total Energy Consumed by the Transportation Se...
# 63  1949  2018  Total Energy Consumed by the Transportation Se...
# 64  1949  2018  Total Energy Consumed by the Transportation Se...
# 65  1949  2018  Total Energy Consumed by the Transportation Se...
# 66  1949  2018  Total Energy Consumed by the Transportation Se...
# 67  1949  2018  Total Energy Consumed by the Transportation Se...
# 68  1949  2018  Total Energy Consumed by the Transportation Se...
# 69  1949  2018  Total Energy Consumed by the Transportation Se...
#
#             sector        series_id         units                   updated  \
# 0   Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# 1   Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# 2   Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# 3   Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# 4   Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# 5   Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# 6   Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# 7   Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# 8   Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# 9   Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# 10  Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# 11  Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# 12  Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# 13  Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# 14  Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# 15  Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# 16  Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# 17  Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# 18  Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# 19  Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# 20  Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# 21  Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# 22  Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# 23  Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# 24  Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# 25  Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# 26  Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# 27  Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# 28  Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# 29  Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# ..             ...              ...           ...                       ...
# 40  Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# 41  Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# 42  Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# 43  Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# 44  Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# 45  Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# 46  Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# 47  Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# 48  Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# 49  Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# 50  Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# 51  Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# 52  Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# 53  Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# 54  Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# 55  Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# 56  Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# 57  Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# 58  Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# 59  Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# 60  Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# 61  Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# 62  Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# 63  Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# 64  Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# 65  Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# 66  Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# 67  Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# 68  Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# 69  Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
#
#     year      value
# 0   2018  28390.532
# 1   2017  28014.167
# 2   2016  27785.537
# 3   2015  27238.037
# 4   2014  26868.857
# 5   2013  26611.709
# 6   2012  26125.738
# 7   2011  26598.624
# 8   2010  26978.400
# 9   2009  26588.888
# 10  2008  27421.586
# 11  2007  28815.197
# 12  2006  28696.876
# 13  2005  28260.752
# 14  2004  27826.509
# 15  2003  26881.050
# 16  2002  26807.811
# 17  2001  26242.128
# 18  2000  26515.505
# 19  1999  25916.020
# 20  1998  25224.513
# 21  1997  24722.565
# 22  1996  24419.296
# 23  1995  23811.912
# 24  1994  23318.674
# 25  1993  22670.767
# 26  1992  22415.073
# 27  1991  22117.987
# 28  1990  22418.964
# 29  1989  22478.575
# ..   ...        ...
# 40  1978  20617.064
# 41  1977  19821.590
# 42  1976  19100.798
# 43  1975  18245.003
# 44  1974  18120.419
# 45  1973  18612.780
# 46  1972  17717.291
# 47  1971  16730.053
# 48  1970  16098.249
# 49  1969  15506.506
# 50  1968  14865.775
# 51  1967  13752.076
# 52  1966  13100.235
# 53  1965  12432.456
# 54  1964  11997.007
# 55  1963  11653.755
# 56  1962  11219.481
# 57  1961  10769.126
# 58  1960  10595.943
# 59  1959  10348.530
# 60  1958  10004.101
# 61  1957   9896.269
# 62  1956   9859.364
# 63  1955   9550.205
# 64  1954   8902.617
# 65  1953   9123.022
# 66  1952   9002.752
# 67  1951   9041.892
# 68  1950   8492.473
# 69  1949   7990.015
#
# [70 rows x 9 columns]
