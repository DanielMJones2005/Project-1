# %%
# Energy Consumption by Sector

# Dependencies: Industrials
# %matplotlib inline

import requests
import csv
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.stats as stats

# import api_key from config file: Industrials
from api_keys import api_key

# %%
# Industrial
series_url = "http://api.eia.gov/series/?" + "api_key=" + api_key + "&series_id="

header_df = pd.DataFrame()
# # set up additional columns to hold header information
header_df["pk_id"] = ""
header_df["sector"] = ""
header_df["energy_source"] = ""
header_df["frequency"] = ""
header_df["name"] = ""
header_df["source"] = ""
header_df["series_id"] = ""
header_df["unit_long"] = ""
header_df["unit_short"] = ""

header_df["data_for"] = ""

line_df = pd.DataFrame()
# # set up additional columns to hold line information
line_df["fk_id"] = ""
line_df["year"] = ""
line_df["month"] = ""
line_df["value"] = ""

consumption_pre = "TOTAL."
consumption_post = ".A"
consumption_source = ["TEICBUS"
                      ]

pkid = 0
e_source = "Total Energy"
    
for count, cs in enumerate(consumption_source, start=pkid):
    query_url = series_url + consumption_pre + cs + consumption_post
    cons_json = requests.get(query_url).json()
    header_df = header_df.append({"pk_id" : count,
                                  "sector" : "Industrial",
                                  "energy_source" : e_source,
                                  "frequency" : "Annual",
                                  "name" : cons_json["series"][0]['name'],
                                  "source" : "EIA, U.S. Energy Information Administration",
                                  "series_id" : cons_json["series"][0]['series_id'], 
                                  "unit_long" : cons_json["series"][0]['units'],
                                  "data_for" : "Consumption",
                                 } , ignore_index=True )
    
    for dt in cons_json["series"][0]["data"]:
            line_df = line_df.append({"fk_id" : count,
                                      "year" : dt[0],
                                      "month" : 13,
                                      "value" : dt[1]
                               } , ignore_index=True )
    pkid = count
    
print("-----------------------------")
print("Data Retrieval Complete for Industrial Consumption")
print("-----------------------------")

header_df
# Out:
# -----------------------------
# Data Retrieval Complete for Industrial Consumption
# -----------------------------
#   pk_id      sector energy_source frequency  \
# 0     0  Industrial  Total Energy    Annual
#
#                                                 name  \
# 0  Total Energy Consumed by the Industrial Sector...
#
#                                         source        series_id     unit_long  \
# 0  EIA, U.S. Energy Information Administration  TOTAL.TEICBUS.A  Trillion Btu
#
#   unit_short     data_for
# 0        NaN  Consumption

# %%
line_df.head()
# Out:
#   fk_id  year month      value
# 0     0  2018    13  32617.767
# 1     0  2017    13  32005.673
# 2     0  2016    13  31452.839
# 3     0  2015    13  31471.524
# 4     0  2014    13  31797.941

# %%
line_df2 = line_df.rename(columns={"fk_id": "pk_id"})
line_df2.head()
# Out:
#   pk_id  year month      value
# 0     0  2018    13  32617.767
# 1     0  2017    13  32005.673
# 2     0  2016    13  31452.839
# 3     0  2015    13  31471.524
# 4     0  2014    13  31797.941

# %%
ind_df = pd.merge(line_df2, header_df, on="pk_id")
ind_df.head()
# Out:
#   pk_id  year month      value      sector energy_source frequency  \
# 0     0  2018    13  32617.767  Industrial  Total Energy    Annual
# 1     0  2017    13  32005.673  Industrial  Total Energy    Annual
# 2     0  2016    13  31452.839  Industrial  Total Energy    Annual
# 3     0  2015    13  31471.524  Industrial  Total Energy    Annual
# 4     0  2014    13  31797.941  Industrial  Total Energy    Annual
#
#                                                 name  \
# 0  Total Energy Consumed by the Industrial Sector...
# 1  Total Energy Consumed by the Industrial Sector...
# 2  Total Energy Consumed by the Industrial Sector...
# 3  Total Energy Consumed by the Industrial Sector...
# 4  Total Energy Consumed by the Industrial Sector...
#
#                                         source        series_id     unit_long  \
# 0  EIA, U.S. Energy Information Administration  TOTAL.TEICBUS.A  Trillion Btu
# 1  EIA, U.S. Energy Information Administration  TOTAL.TEICBUS.A  Trillion Btu
# 2  EIA, U.S. Energy Information Administration  TOTAL.TEICBUS.A  Trillion Btu
# 3  EIA, U.S. Energy Information Administration  TOTAL.TEICBUS.A  Trillion Btu
# 4  EIA, U.S. Energy Information Administration  TOTAL.TEICBUS.A  Trillion Btu
#
#   unit_short     data_for
# 0        NaN  Consumption
# 1        NaN  Consumption
# 2        NaN  Consumption
# 3        NaN  Consumption
# 4        NaN  Consumption

# %%
ind_df.tail()
# Out:
#    pk_id  year month      value      sector energy_source frequency  \
# 65     0  1953    13  18211.754  Industrial  Total Energy    Annual
# 66     0  1952    13  17311.362  Industrial  Total Energy    Annual
# 67     0  1951    13  17678.532  Industrial  Total Energy    Annual
# 68     0  1950    13  16241.423  Industrial  Total Energy    Annual
# 69     0  1949    13  14723.587  Industrial  Total Energy    Annual
#
#                                                  name  \
# 65  Total Energy Consumed by the Industrial Sector...
# 66  Total Energy Consumed by the Industrial Sector...
# 67  Total Energy Consumed by the Industrial Sector...
# 68  Total Energy Consumed by the Industrial Sector...
# 69  Total Energy Consumed by the Industrial Sector...
#
#                                          source        series_id  \
# 65  EIA, U.S. Energy Information Administration  TOTAL.TEICBUS.A
# 66  EIA, U.S. Energy Information Administration  TOTAL.TEICBUS.A
# 67  EIA, U.S. Energy Information Administration  TOTAL.TEICBUS.A
# 68  EIA, U.S. Energy Information Administration  TOTAL.TEICBUS.A
# 69  EIA, U.S. Energy Information Administration  TOTAL.TEICBUS.A
#
#        unit_long unit_short     data_for
# 65  Trillion Btu        NaN  Consumption
# 66  Trillion Btu        NaN  Consumption
# 67  Trillion Btu        NaN  Consumption
# 68  Trillion Btu        NaN  Consumption
# 69  Trillion Btu        NaN  Consumption

# %%
format_ind_df = pd.DataFrame(ind_df, columns=["sector","energy_source","year","value","unit_long"])
format_ind_df = format_ind_df.rename(columns={"energy_source": "source", "unit_long": "units"
                                         })

format_ind_df.head()
# Out:
#        sector        source  year      value         units
# 0  Industrial  Total Energy  2018  32617.767  Trillion Btu
# 1  Industrial  Total Energy  2017  32005.673  Trillion Btu
# 2  Industrial  Total Energy  2016  31452.839  Trillion Btu
# 3  Industrial  Total Energy  2015  31471.524  Trillion Btu
# 4  Industrial  Total Energy  2014  31797.941  Trillion Btu

# %%
# Commercial
url = "http://api.eia.gov/category/?"
query_url=f"{url}api_key={api_key}&series_id=TOTAL.CLCCBUS.A"

response=requests.get(query_url)
print(response.status_code)

query_url=f"{url}api_key={api_key}&category_id=711251"

eia_json = requests.get(query_url).json()

url = "http://api.eia.gov/series/?api_key="
api_code1="&series_id=TOTAL."
api_code2=".A"
category=["TECCBUS"]
# Out:
# 200

# %%
start = []
end = []
f = []
name = []
sector = []
series_id = []
units = []
updated = []
year = []
value = []
data = []
count_cat = 0

for cat in category:
        query_url = url + api_key + api_code1 + cat + api_code2
        count_cat = count_cat + 1
        print("Processing Record " + str(count_cat) + " | " + cat)

        consumption_response = requests.get(query_url).json()
        
       
        data.append(consumption_response["series"][0]["data"])
        ln = (len(data[0]))

        for i in range(0,ln):
            start.append(consumption_response["series"][0]["start"])
            end.append(consumption_response["series"][0]["end"])
            f.append(consumption_response["series"][0]["f"])
            name.append(consumption_response["series"][0]["name"])
            sector.append(consumption_response["series"][0]["name"].split(" ")[5])
            series_id.append(consumption_response["series"][0]["series_id"])
            units.append(consumption_response["series"][0]["units"])
            updated.append(consumption_response["series"][0]["updated"])
            year.append(consumption_response["series"][0]["data"][i][0])
            value.append(consumption_response["series"][0]["data"][i][1])
print("-----------------------------")
print("Data Retrieval Complete")
print("---------------------")
# Out:
# Processing Record 1 | TECCBUS
# -----------------------------
# Data Retrieval Complete
# ---------------------

# %%
consumption_comm_df = pd.DataFrame({
   "start":start,
   "end":end,
   "name": name,
   "sector": sector,
   "series_id": series_id,
   "units": units,
   "updated": updated,
   "year": year,
   "value": value
})
consumption_comm_df["source"] = consumption_response["series"][0]["name"].split("Consumed")[0]
consumption_comm_df.head()
# Out:
#   start   end                                               name      sector  \
# 0  1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# 1  1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# 2  1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# 3  1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# 4  1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
#
#          series_id         units                   updated  year      value  \
# 0  TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  2018  18607.551
# 1  TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  2017  17899.252
# 2  TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  2016  18030.223
# 3  TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  2015  18156.728
# 4  TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  2014  18264.465
#
#           source
# 0  Total Energy
# 1  Total Energy
# 2  Total Energy
# 3  Total Energy
# 4  Total Energy

# %%
consumption_comm_df.tail()
# Out:
#    start   end                                               name      sector  \
# 65  1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# 66  1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# 67  1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# 68  1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# 69  1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
#
#           series_id         units                   updated  year     value  \
# 65  TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  1953  3770.982
# 66  TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  1952  3873.385
# 67  TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  1951  3873.226
# 68  TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  1950  3893.298
# 69  TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  1949  3668.816
#
#            source
# 65  Total Energy
# 66  Total Energy
# 67  Total Energy
# 68  Total Energy
# 69  Total Energy

# %%
format_comm_df = pd.DataFrame(consumption_comm_df, columns=["sector","source","year","value","units"])
format_comm_df.head()
# Out:
#        sector         source  year      value         units
# 0  Commercial  Total Energy   2018  18607.551  Trillion Btu
# 1  Commercial  Total Energy   2017  17899.252  Trillion Btu
# 2  Commercial  Total Energy   2016  18030.223  Trillion Btu
# 3  Commercial  Total Energy   2015  18156.728  Trillion Btu
# 4  Commercial  Total Energy   2014  18264.465  Trillion Btu

# %%
# Transportation
url = "http://api.eia.gov/series/?api_key="
api_code1="&series_id=TOTAL."
api_code2=".A"
category=["TEACBUS"]

# %%
start = []
end = []
f = []
name = []
sector = []
series_id = []
units = []
updated = []
year = []
value = []
data = []
count_cat = 0

for cat in category:
        query_url = url + api_key + api_code1 + cat + api_code2
        count_cat = count_cat + 1
        print("Processing Record " + str(count_cat) + " | " + cat)

        consumption_response = requests.get(query_url).json()
        
       
        data.append(consumption_response["series"][0]["data"])
        ln = (len(data[0]))

        for i in range(0,ln):
            start.append(consumption_response["series"][0]["start"])
            end.append(consumption_response["series"][0]["end"])
            f.append(consumption_response["series"][0]["f"])
            name.append(consumption_response["series"][0]["name"])
            sector.append(consumption_response["series"][0]["name"].split(" ")[5])
            series_id.append(consumption_response["series"][0]["series_id"])
            units.append(consumption_response["series"][0]["units"])
            updated.append(consumption_response["series"][0]["updated"])
            year.append(consumption_response["series"][0]["data"][i][0])
            value.append(consumption_response["series"][0]["data"][i][1])

print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Processing Record 1 | TEACBUS
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
consumption_trans_df = pd.DataFrame({
   "start":start,
   "end":end,
   "name": name,
   "sector": sector,
   "series_id": series_id,
   "units": units,
   "updated": updated,
   "year": year,
   "value": value
})
consumption_trans_df["source"] = consumption_response["series"][0]["name"].split("Consumed")[0]
consumption_trans_df.head()
# Out:
#   start   end                                               name  \
# 0  1949  2018  Total Energy Consumed by the Transportation Se...
# 1  1949  2018  Total Energy Consumed by the Transportation Se...
# 2  1949  2018  Total Energy Consumed by the Transportation Se...
# 3  1949  2018  Total Energy Consumed by the Transportation Se...
# 4  1949  2018  Total Energy Consumed by the Transportation Se...
#
#            sector        series_id         units                   updated  \
# 0  Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# 1  Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# 2  Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# 3  Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# 4  Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
#
#    year      value         source
# 0  2018  28390.532  Total Energy
# 1  2017  28014.167  Total Energy
# 2  2016  27785.537  Total Energy
# 3  2015  27238.037  Total Energy
# 4  2014  26868.857  Total Energy

# %%
consumption_trans_df.tail()
# Out:
#    start   end                                               name  \
# 65  1949  2018  Total Energy Consumed by the Transportation Se...
# 66  1949  2018  Total Energy Consumed by the Transportation Se...
# 67  1949  2018  Total Energy Consumed by the Transportation Se...
# 68  1949  2018  Total Energy Consumed by the Transportation Se...
# 69  1949  2018  Total Energy Consumed by the Transportation Se...
#
#             sector        series_id         units                   updated  \
# 65  Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# 66  Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# 67  Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# 68  Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
# 69  Transportation  TOTAL.TEACBUS.A  Trillion Btu  2019-05-23T15:52:44-0400
#
#     year     value         source
# 65  1953  9123.022  Total Energy
# 66  1952  9002.752  Total Energy
# 67  1951  9041.892  Total Energy
# 68  1950  8492.473  Total Energy
# 69  1949  7990.015  Total Energy

# %%
format_trans_df = pd.DataFrame(consumption_trans_df, columns=["sector","source","year","value","units"])
format_trans_df.head()
# Out:
#            sector         source  year      value         units
# 0  Transportation  Total Energy   2018  28390.532  Trillion Btu
# 1  Transportation  Total Energy   2017  28014.167  Trillion Btu
# 2  Transportation  Total Energy   2016  27785.537  Trillion Btu
# 3  Transportation  Total Energy   2015  27238.037  Trillion Btu
# 4  Transportation  Total Energy   2014  26868.857  Trillion Btu

# %%
# Residential
#http://api.eia.gov/series/?api_key=YOUR_API_KEY_HERE&series_id=TOTAL.TERCBUS.A

url = "http://api.eia.gov/series/?api_key="
api_code1 = "&series_id=TOTAL."
api_energy_source = "TERCBUS"
api_period = ".A"

# %%
start = []
end = []
f = []
name = []
sector = []
sec = "Residential"
source = []
energy_source = "Total Energy"
series_id = []
units = []
updated = []
year = []
value = []
count_st = 0

query_url = url + api_key + api_code1 + api_energy_source + api_period
consume_res_resp = requests.get(query_url).json()
     
data = []
data.append(consume_res_resp["series"][0]["data"])
ln = (len(data[0]))

for i in range(0, ln):

    start.append(consume_res_resp["series"][0]["start"])
    end.append(consume_res_resp["series"][0]["end"])
    f.append(consume_res_resp["series"][0]["f"])
    name.append(consume_res_resp["series"][0]["name"])
    source.append(energy_source)
    sector.append(sec)
    series_id.append(consume_res_resp["series"][0]["series_id"])
    units.append(consume_res_resp["series"][0]["units"])
    updated.append(consume_res_resp["series"][0]["updated"])
    year.append(consume_res_resp["series"][0]["data"][i][0])
    value.append(consume_res_resp["series"][0]["data"][i][1])
        
print("-----------------------------")
print("Data Retrieval Complete")      
print("-----------------------------")
# Out:
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Create DataFrame
energy_consume_resi_df = pd.DataFrame({
    "start": start,
    "end": end,
    "f": f,
    "name": name,
    "source": source,
    "sector": sector,
    "series_id": series_id,
    "units": units,
    "updated": updated,
    "year": year,
    "value": value
    
})
energy_consume_resi_df.head()
# Out:
#   start   end  f                                               name  \
# 0  1949  2018  A  Total Energy Consumed by the Residential Secto...
# 1  1949  2018  A  Total Energy Consumed by the Residential Secto...
# 2  1949  2018  A  Total Energy Consumed by the Residential Secto...
# 3  1949  2018  A  Total Energy Consumed by the Residential Secto...
# 4  1949  2018  A  Total Energy Consumed by the Residential Secto...
#
#          source       sector        series_id         units  \
# 0  Total Energy  Residential  TOTAL.TERCBUS.A  Trillion Btu
# 1  Total Energy  Residential  TOTAL.TERCBUS.A  Trillion Btu
# 2  Total Energy  Residential  TOTAL.TERCBUS.A  Trillion Btu
# 3  Total Energy  Residential  TOTAL.TERCBUS.A  Trillion Btu
# 4  Total Energy  Residential  TOTAL.TERCBUS.A  Trillion Btu
#
#                     updated  year      value
# 0  2019-06-24T11:59:37-0400  2018  21621.074
# 1  2019-06-24T11:59:37-0400  2017  19889.581
# 2  2019-06-24T11:59:37-0400  2016  20181.113
# 3  2019-06-24T11:59:37-0400  2015  20616.830
# 4  2019-06-24T11:59:37-0400  2014  21444.938

# %%
energy_consume_resi_df.tail()
# Out:
#    start   end  f                                               name  \
# 65  1949  2018  A  Total Energy Consumed by the Residential Secto...
# 66  1949  2018  A  Total Energy Consumed by the Residential Secto...
# 67  1949  2018  A  Total Energy Consumed by the Residential Secto...
# 68  1949  2018  A  Total Energy Consumed by the Residential Secto...
# 69  1949  2018  A  Total Energy Consumed by the Residential Secto...
#
#           source       sector        series_id         units  \
# 65  Total Energy  Residential  TOTAL.TERCBUS.A  Trillion Btu
# 66  Total Energy  Residential  TOTAL.TERCBUS.A  Trillion Btu
# 67  Total Energy  Residential  TOTAL.TERCBUS.A  Trillion Btu
# 68  Total Energy  Residential  TOTAL.TERCBUS.A  Trillion Btu
# 69  Total Energy  Residential  TOTAL.TERCBUS.A  Trillion Btu
#
#                      updated  year     value
# 65  2019-06-24T11:59:37-0400  1953  6558.748
# 66  2019-06-24T11:59:37-0400  1952  6560.243
# 67  2019-06-24T11:59:37-0400  1951  6380.193
# 68  2019-06-24T11:59:37-0400  1950  5988.553
# 69  2019-06-24T11:59:37-0400  1949  5599.250

# %%
format_resi_df = pd.DataFrame(energy_consume_resi_df, columns=["sector","source","year","value","units"])
format_resi_df.head()
# Out:
#         sector        source  year      value         units
# 0  Residential  Total Energy  2018  21621.074  Trillion Btu
# 1  Residential  Total Energy  2017  19889.581  Trillion Btu
# 2  Residential  Total Energy  2016  20181.113  Trillion Btu
# 3  Residential  Total Energy  2015  20616.830  Trillion Btu
# 4  Residential  Total Energy  2014  21444.938  Trillion Btu

# %%
# master consumption DataFrame
master_consum_df = pd.DataFrame()
master_consum_df["sector"] = []
master_consum_df["source"] = []
master_consum_df["year"] = []
master_consum_df["value"] = []
master_consum_df["units"] = []

master_consum_df = master_consum_df.append(format_ind_df)
master_consum_df = master_consum_df.append(format_comm_df)
master_consum_df = master_consum_df.append(format_trans_df)
master_consum_df = master_consum_df.append(format_resi_df)
master_consum_df
# Out:
#          sector        source  year      value         units
# 0    Industrial  Total Energy  2018  32617.767  Trillion Btu
# 1    Industrial  Total Energy  2017  32005.673  Trillion Btu
# 2    Industrial  Total Energy  2016  31452.839  Trillion Btu
# 3    Industrial  Total Energy  2015  31471.524  Trillion Btu
# 4    Industrial  Total Energy  2014  31797.941  Trillion Btu
# 5    Industrial  Total Energy  2013  31627.437  Trillion Btu
# 6    Industrial  Total Energy  2012  31060.724  Trillion Btu
# 7    Industrial  Total Energy  2011  30981.322  Trillion Btu
# 8    Industrial  Total Energy  2010  30670.436  Trillion Btu
# 9    Industrial  Total Energy  2009  28465.439  Trillion Btu
# 10   Industrial  Total Energy  2008  31333.358  Trillion Btu
# 11   Industrial  Total Energy  2007  32384.515  Trillion Btu
# 12   Industrial  Total Energy  2006  32390.355  Trillion Btu
# 13   Industrial  Total Energy  2005  32441.115  Trillion Btu
# 14   Industrial  Total Energy  2004  33515.280  Trillion Btu
# 15   Industrial  Total Energy  2003  32552.715  Trillion Btu
# 16   Industrial  Total Energy  2002  32660.366  Trillion Btu
# 17   Industrial  Total Energy  2001  32718.499  Trillion Btu
# 18   Industrial  Total Energy  2000  34662.130  Trillion Btu
# 19   Industrial  Total Energy  1999  34762.524  Trillion Btu
# 20   Industrial  Total Energy  1998  34841.110  Trillion Btu
# 21   Industrial  Total Energy  1997  35198.990  Trillion Btu
# 22   Industrial  Total Energy  1996  34902.978  Trillion Btu
# 23   Industrial  Total Energy  1995  33969.227  Trillion Btu
# 24   Industrial  Total Energy  1994  33519.691  Trillion Btu
# 25   Industrial  Total Energy  1993  32618.544  Trillion Btu
# 26   Industrial  Total Energy  1992  32570.887  Trillion Btu
# 27   Industrial  Total Energy  1991  31399.342  Trillion Btu
# 28   Industrial  Total Energy  1990  31801.602  Trillion Btu
# 29   Industrial  Total Energy  1989  31327.767  Trillion Btu
# ..          ...           ...   ...        ...           ...
# 40  Residential  Total Energy  1978  16132.287  Trillion Btu
# 41  Residential  Total Energy  1977  15661.713  Trillion Btu
# 42  Residential  Total Energy  1976  15410.259  Trillion Btu
# 43  Residential  Total Energy  1975  14813.400  Trillion Btu
# 44  Residential  Total Energy  1974  14654.336  Trillion Btu
# 45  Residential  Total Energy  1973  14897.351  Trillion Btu
# 46  Residential  Total Energy  1972  14857.045  Trillion Btu
# 47  Residential  Total Energy  1971  14246.200  Trillion Btu
# 48  Residential  Total Energy  1970  13765.758  Trillion Btu
# 49  Residential  Total Energy  1969  13169.156  Trillion Btu
# 50  Residential  Total Energy  1968  12336.290  Trillion Btu
# 51  Residential  Total Energy  1967  11639.275  Trillion Btu
# 52  Residential  Total Energy  1966  11168.630  Trillion Btu
# 53  Residential  Total Energy  1965  10639.387  Trillion Btu
# 54  Residential  Total Energy  1964  10240.574  Trillion Btu
# 55  Residential  Total Energy  1963   9988.479  Trillion Btu
# 56  Residential  Total Energy  1962   9782.420  Trillion Btu
# 57  Residential  Total Energy  1961   9286.024  Trillion Btu
# 58  Residential  Total Energy  1960   9039.418  Trillion Btu
# 59  Residential  Total Energy  1959   8411.866  Trillion Btu
# 60  Residential  Total Energy  1958   8200.674  Trillion Btu
# 61  Residential  Total Energy  1957   7712.000  Trillion Btu
# 62  Residential  Total Energy  1956   7662.725  Trillion Btu
# 63  Residential  Total Energy  1955   7277.988  Trillion Btu
# 64  Residential  Total Energy  1954   6846.058  Trillion Btu
# 65  Residential  Total Energy  1953   6558.748  Trillion Btu
# 66  Residential  Total Energy  1952   6560.243  Trillion Btu
# 67  Residential  Total Energy  1951   6380.193  Trillion Btu
# 68  Residential  Total Energy  1950   5988.553  Trillion Btu
# 69  Residential  Total Energy  1949   5599.250  Trillion Btu
#
# [280 rows x 5 columns]

# %%
master_consum_df.shape
# Out:
# (280, 5)

# %%
master_consum_df.dtypes
# Out:
# sector     object
# source     object
# year       object
# value     float64
# units      object
# dtype: object

# %%
master_consum_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 280 entries, 0 to 69
# Data columns (total 5 columns):
# sector    280 non-null object
# source    280 non-null object
# year      280 non-null object
# value     280 non-null float64
# units     280 non-null object
# dtypes: float64(1), object(4)
# memory usage: 13.1+ KB

# %%
master_consum_df.describe()
# Out:
#               value
# count    280.000000
# mean   18746.007143
# std     8485.537439
# min     3668.816000
# 25%    11630.982750
# 50%    18138.573500
# 75%    26287.001750
# max    35198.990000

# %%
master_consum_df = master_consum_df.sort_values(by='year',ascending=True)
master_consum_df
# Out:
#             sector         source  year      value         units
# 69      Commercial  Total Energy   1949   3668.816  Trillion Btu
# 69  Transportation  Total Energy   1949   7990.015  Trillion Btu
# 69      Industrial   Total Energy  1949  14723.587  Trillion Btu
# 69     Residential   Total Energy  1949   5599.250  Trillion Btu
# 68      Industrial   Total Energy  1950  16241.423  Trillion Btu
# 68  Transportation  Total Energy   1950   8492.473  Trillion Btu
# 68      Commercial  Total Energy   1950   3893.298  Trillion Btu
# 68     Residential   Total Energy  1950   5988.553  Trillion Btu
# 67      Commercial  Total Energy   1951   3873.226  Trillion Btu
# 67      Industrial   Total Energy  1951  17678.532  Trillion Btu
# 67  Transportation  Total Energy   1951   9041.892  Trillion Btu
# 67     Residential   Total Energy  1951   6380.193  Trillion Btu
# 66      Industrial   Total Energy  1952  17311.362  Trillion Btu
# 66     Residential   Total Energy  1952   6560.243  Trillion Btu
# 66      Commercial  Total Energy   1952   3873.385  Trillion Btu
# 66  Transportation  Total Energy   1952   9002.752  Trillion Btu
# 65     Residential   Total Energy  1953   6558.748  Trillion Btu
# 65      Industrial   Total Energy  1953  18211.754  Trillion Btu
# 65      Commercial  Total Energy   1953   3770.982  Trillion Btu
# 65  Transportation  Total Energy   1953   9123.022  Trillion Btu
# 64  Transportation  Total Energy   1954   8902.617  Trillion Btu
# 64      Commercial  Total Energy   1954   3732.921  Trillion Btu
# 64      Industrial   Total Energy  1954  17157.695  Trillion Btu
# 64     Residential   Total Energy  1954   6846.058  Trillion Btu
# 63      Industrial   Total Energy  1955  19484.608  Trillion Btu
# 63  Transportation  Total Energy   1955   9550.205  Trillion Btu
# 63      Commercial  Total Energy   1955   3895.140  Trillion Btu
# 63     Residential   Total Energy  1955   7277.988  Trillion Btu
# 62     Residential   Total Energy  1956   7662.725  Trillion Btu
# 62      Commercial  Total Energy   1956   4022.859  Trillion Btu
# ..             ...            ...   ...        ...           ...
# 7       Commercial  Total Energy   2011  17981.378  Trillion Btu
# 7       Industrial   Total Energy  2011  30981.322  Trillion Btu
# 6       Commercial  Total Energy   2012  17421.351  Trillion Btu
# 6       Industrial   Total Energy  2012  31060.724  Trillion Btu
# 6      Residential   Total Energy  2012  19869.589  Trillion Btu
# 6   Transportation  Total Energy   2012  26125.738  Trillion Btu
# 5   Transportation  Total Energy   2013  26611.709  Trillion Btu
# 5       Industrial   Total Energy  2013  31627.437  Trillion Btu
# 5      Residential   Total Energy  2013  21051.185  Trillion Btu
# 5       Commercial  Total Energy   2013  17929.446  Trillion Btu
# 4       Commercial  Total Energy   2014  18264.465  Trillion Btu
# 4       Industrial   Total Energy  2014  31797.941  Trillion Btu
# 4   Transportation  Total Energy   2014  26868.857  Trillion Btu
# 4      Residential   Total Energy  2014  21444.938  Trillion Btu
# 3   Transportation  Total Energy   2015  27238.037  Trillion Btu
# 3      Residential   Total Energy  2015  20616.830  Trillion Btu
# 3       Commercial  Total Energy   2015  18156.728  Trillion Btu
# 3       Industrial   Total Energy  2015  31471.524  Trillion Btu
# 2      Residential   Total Energy  2016  20181.113  Trillion Btu
# 2       Commercial  Total Energy   2016  18030.223  Trillion Btu
# 2       Industrial   Total Energy  2016  31452.839  Trillion Btu
# 2   Transportation  Total Energy   2016  27785.537  Trillion Btu
# 1   Transportation  Total Energy   2017  28014.167  Trillion Btu
# 1       Industrial   Total Energy  2017  32005.673  Trillion Btu
# 1       Commercial  Total Energy   2017  17899.252  Trillion Btu
# 1      Residential   Total Energy  2017  19889.581  Trillion Btu
# 0      Residential   Total Energy  2018  21621.074  Trillion Btu
# 0   Transportation  Total Energy   2018  28390.532  Trillion Btu
# 0       Commercial  Total Energy   2018  18607.551  Trillion Btu
# 0       Industrial   Total Energy  2018  32617.767  Trillion Btu
#
# [280 rows x 5 columns]

# %%
x_ind = master_consum_df[master_consum_df.sector=="Industrial"].year[-10:]
x_comm = master_consum_df[master_consum_df.sector=="Commercial"].year[-10:]
x_trans = master_consum_df[master_consum_df.sector=="Transportation"].year[-10:]
x_resi = master_consum_df[master_consum_df.sector=="Residential"].year[-10:]


y_ind = master_consum_df[master_consum_df.sector=="Industrial"].value[-10:]
y_comm = master_consum_df[master_consum_df.sector=="Commercial"].value[-10:]
y_trans = master_consum_df[master_consum_df.sector=="Transportation"].value[-10:]
y_resi = master_consum_df[master_consum_df.sector=="Residential"].value[-10:]

# %%
y_columns = ["Industrial", "Transportation", "Residential", "Commercial"]

plt.plot(x_ind, y_ind, color="red", linestyle=(0, (.5,.5)), marker="o")
plt.plot(x_trans, y_trans, color="green", linestyle=(0, (.5,.5)),marker="s")
plt.plot(x_resi, y_resi, color="blue", linestyle=(0, (.5,.5)),marker="d")
plt.plot(x_comm, y_comm, color="black", linestyle=(0, (.5,.5)),marker="^")

plt.legend(y_columns)

plt.title("Total Energy Consumption by Sector")
plt.xlabel("Year")
plt.ylabel("Total Energy Consumed (Trillion Btu)")

plt.grid()


# Save the Figure
plt.savefig('Total Energy_Energy Consumption by Sector.png') 
# Show the Figure
plt.show()

# %%
# Compound Annual Growth

ind_yr_f = master_consum_df[master_consum_df.sector=="Industrial"].year[-10:-9]
comm_yr_f = master_consum_df[master_consum_df.sector=="Commercial"].year[-10:-9]
trans_yr_f = master_consum_df[master_consum_df.sector=="Transportation"].year[-10:-9]
resi_yr_f = master_consum_df[master_consum_df.sector=="Residential"].year[-10:-9]

ind_yr_l = master_consum_df[master_consum_df.sector=="Industrial"].year[-1:]
comm_yr_l = master_consum_df[master_consum_df.sector=="Commercial"].year[-1:]
trans_yr_l = master_consum_df[master_consum_df.sector=="Transportation"].year[-1:]
resi_yr_l = master_consum_df[master_consum_df.sector=="Residential"].year[-1:]

ind_years = int(ind_yr_l) - int(ind_yr_f) + 1
comm_years = int(comm_yr_l) - int(comm_yr_f) + 1
trans_years = int(trans_yr_l) - int(trans_yr_f) + 1
resi_years = int(resi_yr_l) - int(resi_yr_f) + 1

ind_f = master_consum_df[master_consum_df.sector=="Industrial"].value[-10:-9]
comm_f = master_consum_df[master_consum_df.sector=="Commercial"].value[-10:-9]
trans_f = master_consum_df[master_consum_df.sector=="Transportation"].value[-10:-9]
resi_f = master_consum_df[master_consum_df.sector=="Residential"].value[-10:-9]

ind_l = master_consum_df[master_consum_df.sector=="Industrial"].value[-1:]
comm_l = master_consum_df[master_consum_df.sector=="Commercial"].value[-1:]
trans_l = master_consum_df[master_consum_df.sector=="Transportation"].value[-1:]
resi_l = master_consum_df[master_consum_df.sector=="Residential"].value[-1:]

cagr_ind = (int(ind_l) / int(ind_f))**(1/ind_years) - 1
cagr_comm = (int(comm_l) / int(comm_f))**(1/comm_years) - 1
cagr_trans = (int(trans_l) / int(trans_f))**(1/trans_years) - 1
cagr_resi = (int(resi_l) / int(resi_f))**(1/resi_years) - 1

print("Industrial had a CAGR of {:.2%}".format(cagr_ind) + " from " + str(int(ind_yr_f)) + " to " + str(int(ind_yr_l)))
print('Commercial had a CAGR of {:.2%} '.format(cagr_comm) + "from " + str(int(comm_yr_f)) + " to " + str(int(comm_yr_l)))
print('Transportation had a CAGR of {:.2%} '.format(cagr_trans) + "from " + str(int(trans_yr_f)) + " to " + str(int(trans_yr_l)))
print('Residential had a CAGR of {:.2%} '.format(cagr_resi) + "from " + str(int(resi_yr_f)) + " to " + str(int(resi_yr_f)))
# Out:
# Industrial had a CAGR of 1.37% from 2009 to 2018
# Commercial had a CAGR of 0.40% from 2009 to 2018
# Transportation had a CAGR of 0.66% from 2009 to 2018
# Residential had a CAGR of 0.25% from 2009 to 2009

# %%
a = ["Industrial", "Transportation", "Residential", "Commercial"]
b = [(cagr_ind*100), (cagr_trans*100), (cagr_resi*100), (cagr_comm*100)]

color = ["red", "green", "blue", "black"]

time_frame = (" from " + str(int(ind_yr_f)) + " to " + str(int(ind_yr_l)))


# Create horizontal bars
plt.barh(a, b, color=color)

y_i = 0
y_t = 1
y_r = 2
y_c = 3



text_i = (str(round(cagr_ind*100,2)) +"%")
text_t = (str(round(cagr_trans*100,2))  +"%")
text_r = (str(round(cagr_resi*100,2)) +"%")
text_c = (str(round(cagr_comm*100,2)) +"%")


plt.text(cagr_ind*100-.17, y_i, text_i, color="white")
plt.text(cagr_trans*100-.17, y_t, text_t, color="white")
plt.text(cagr_resi*100-.17, y_r, text_r, color="white")
plt.text(cagr_comm*100-.17, y_c, text_c, color="white")


plt.title("Compound Annual Growth Rate (CAGR) % \n"  + time_frame)
plt.xlabel("%")
plt.ylabel("Sector")

plt.tight_layout()

# Save the Figure
plt.savefig('Compound Annual Growth Rate by Sector.png') 

plt.show()

# %%
analysis_ind_df = pd.DataFrame({"year": x_ind,
                                "value": y_ind  
                                })
analysis_ind_df["sector"] = "Industrial"
analysis_ind_df["units"] = "Trillion Btu"


analysis_comm_df = pd.DataFrame({"year": x_comm,
                                "value": y_comm  
                                })
analysis_comm_df["sector"] = "Commercial"
analysis_comm_df["units"] = "Trillion Btu"


analysis_trans_df = pd.DataFrame({"year": x_trans,
                                "value": y_trans  
                                })
analysis_trans_df["sector"] = "Transportation"
analysis_trans_df["units"] = "Trillion Btu"


analysis_resi_df = pd.DataFrame({"year": x_resi,
                                "value": y_resi  
                                })
analysis_resi_df["sector"] = "Residential"
analysis_resi_df["units"] = "Trillion Btu"

# %%
anova_df = pd.DataFrame()
anova_df["year"] = []
anova_df["value"] = []
anova_df["sector"] = []
anova_df["units"] = []

anova_df = anova_df.append(analysis_ind_df)
anova_df = anova_df.append(analysis_comm_df)
anova_df = anova_df.append(analysis_trans_df)
anova_df = anova_df.append(analysis_resi_df)
anova_df
# Out:
#    year      value          sector         units
# 9  2009  28465.439      Industrial  Trillion Btu
# 8  2010  30670.436      Industrial  Trillion Btu
# 7  2011  30981.322      Industrial  Trillion Btu
# 6  2012  31060.724      Industrial  Trillion Btu
# 5  2013  31627.437      Industrial  Trillion Btu
# 4  2014  31797.941      Industrial  Trillion Btu
# 3  2015  31471.524      Industrial  Trillion Btu
# 2  2016  31452.839      Industrial  Trillion Btu
# 1  2017  32005.673      Industrial  Trillion Btu
# 0  2018  32617.767      Industrial  Trillion Btu
# 9  2009  17887.561      Commercial  Trillion Btu
# 8  2010  18058.632      Commercial  Trillion Btu
# 7  2011  17981.378      Commercial  Trillion Btu
# 6  2012  17421.351      Commercial  Trillion Btu
# 5  2013  17929.446      Commercial  Trillion Btu
# 4  2014  18264.465      Commercial  Trillion Btu
# 3  2015  18156.728      Commercial  Trillion Btu
# 2  2016  18030.223      Commercial  Trillion Btu
# 1  2017  17899.252      Commercial  Trillion Btu
# 0  2018  18607.551      Commercial  Trillion Btu
# 9  2009  26588.888  Transportation  Trillion Btu
# 8  2010  26978.400  Transportation  Trillion Btu
# 7  2011  26598.624  Transportation  Trillion Btu
# 6  2012  26125.738  Transportation  Trillion Btu
# 5  2013  26611.709  Transportation  Trillion Btu
# 4  2014  26868.857  Transportation  Trillion Btu
# 3  2015  27238.037  Transportation  Trillion Btu
# 2  2016  27785.537  Transportation  Trillion Btu
# 1  2017  28014.167  Transportation  Trillion Btu
# 0  2018  28390.532  Transportation  Trillion Btu
# 9  2009  21081.368     Residential  Trillion Btu
# 8  2010  21894.159     Residential  Trillion Btu
# 7  2011  21381.247     Residential  Trillion Btu
# 6  2012  19869.589     Residential  Trillion Btu
# 5  2013  21051.185     Residential  Trillion Btu
# 4  2014  21444.938     Residential  Trillion Btu
# 3  2015  20616.830     Residential  Trillion Btu
# 2  2016  20181.113     Residential  Trillion Btu
# 1  2017  19889.581     Residential  Trillion Btu
# 0  2018  21621.074     Residential  Trillion Btu

# %%
# Create a boxplot to compare means
anova_df.boxplot("value", by="sector", figsize=(10, 10))

# %%
# Extract individual groups
group1 = anova_df[anova_df["sector"] == "Commercial"]["value"]
group2 = anova_df[anova_df["sector"] == "Industrial"]["value"]
group3 = anova_df[anova_df["sector"] == "Residential"]["value"]
group4 = anova_df[anova_df["sector"] == "Transportation"]["value"]

# %%
# Perform the ANOVA
stats.f_oneway(group1, group2, group3, group4)
# Out:
# F_onewayResult(statistic=595.2020331471848, pvalue=1.0236119476134707e-30)

# %%
p_test = stats.f_oneway(group1, group2, group3, group4)[1]
print(p_test)
# Out:
# 1.0236119476134707e-30

# %%
if p_test < .05:
    print("The differences between some of the means are statistically significant")
else:
    print("The differences between the means are not statistically significant")
# Out:
# The differences between some of the means are statistically significant

# %%
# Calculate Mean
ind_val = anova_df[anova_df["sector"]=="Industrial"].value
comm_val = anova_df[anova_df["sector"]=="Commercial"].value
trans_val = anova_df[anova_df["sector"]=="Transportation"].value
resi_val = anova_df[anova_df["sector"]=="Residential"].value

ind_avg = ind_val.mean()
comm_avg = comm_val.mean()
trans_avg = trans_val.mean()
resi_avg = resi_val.mean()

print(ind_avg)
print(comm_avg)
print(trans_avg)
print(resi_avg)
# Out:
# 31215.110200000003
# 18023.6587
# 27120.0489
# 20903.1084

# %%
stats.ttest_ind(ind_val, comm_val, equal_var=False)
# Out:
# Ttest_indResult(statistic=36.147992778512126, pvalue=3.2825166921803944e-12)

# %%
stats.ttest_ind(ind_val, trans_val, equal_var=False)
# Out:
# Ttest_indResult(statistic=9.738232302731404, pvalue=5.310723781756896e-08)

# %%
stats.ttest_ind(ind_val, resi_val, equal_var=False)
# Out:
# Ttest_indResult(statistic=24.508854744679795, pvalue=8.039249850013244e-14)

# %%
stats.ttest_ind(comm_val, trans_val, equal_var=False)
# Out:
# Ttest_indResult(statistic=-36.53217616093951, pvalue=1.0647296195642882e-13)

# %%
stats.ttest_ind(comm_val, resi_val, equal_var=False)
# Out:
# Ttest_indResult(statistic=-11.546039402752209, pvalue=7.285710924812013e-08)

# %%
stats.ttest_ind(trans_val, resi_val, equal_var=False)
# Out:
# Ttest_indResult(statistic=19.108406151817306, pvalue=2.1135540794463932e-13)

# %%
ind_vs_comm_p = stats.ttest_ind(ind_val, comm_val, equal_var=False)[1]
ind_vs_trans_p = stats.ttest_ind(ind_val, trans_val, equal_var=False)[1]
ind_vs_resi_p = stats.ttest_ind(ind_val, resi_val, equal_var=False)[1]
comm_vs_trans_p = stats.ttest_ind(comm_val, trans_val, equal_var=False)[1]
comm_vs_resi_p = stats.ttest_ind(comm_val, resi_val, equal_var=False)[1]
trans_vs_resi_p = stats.ttest_ind(trans_val, resi_val, equal_var=False)[1]

# %%
if ind_vs_comm_p < .05:
    print("ind_vs_comm: \n  The differences between some of the means are statistically significant")
else:
    print("ind_vs_comm: \n  The differences between the means are not statistically significant")
    

if ind_vs_trans_p < .05:
    print("ind_vs_trans: \n  The differences between some of the means are statistically significant")
else:
    print("ind_vs_trans: \n  The differences between the means are not statistically significant")    
   

if ind_vs_resi_p < .05:
    print("ind_vs_resi: \n  The differences between some of the means are statistically significant")
else:
    print("ind_vs_resi: \n  The differences between the means are not statistically significant") 
    
    
if comm_vs_trans_p < .05:
    print("comm_vs_trans: \n  The differences between some of the means are statistically significant")
else:
    print("comm_vs_trans: \n  The differences between the means are not statistically significant")  

    
if comm_vs_resi_p < .05:
    print("comm_vs_resi: \n  The differences between some of the means are statistically significant")
else:
    print("comm_vs_resi: \n  The differences between the means are not statistically significant")  

       
if trans_vs_resi_p < .05:
    print("trans_vs_resi: \n  The differences between some of the means are statistically significant")
else:
    print("trans_vs_resi: \n  The differences between the means are not statistically significant")
# Out:
# ind_vs_comm:
#   The differences between some of the means are statistically significant
# ind_vs_trans:
#   The differences between some of the means are statistically significant
# ind_vs_resi:
#   The differences between some of the means are statistically significant
# comm_vs_trans:
#   The differences between some of the means are statistically significant
# comm_vs_resi:
#   The differences between some of the means are statistically significant
# trans_vs_resi:
#   The differences between some of the means are statistically significant
