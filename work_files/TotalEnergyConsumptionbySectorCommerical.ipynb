# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import requests
from pprint import pprint

# Import API key
from api_keys import api_key

# %%
url = "http://api.eia.gov/category/?"
query_url=f"{url}api_key={api_key}&series_id=TOTAL.CLCCBUS.A"

response=requests.get(query_url)
print(response.status_code)
# Out:
# 200

# %%
url = "http://api.eia.gov/category/?"
query_url=f"{url}api_key={api_key}&category_id=711251"
print(query_url)

eia_json = requests.get(query_url).json()

pprint(eia_json)
# Out:
# http://api.eia.gov/category/?api_key=d7c7d5a92f23e68e5710fc5cfbd273dc&category_id=711251
# {'category': {'category_id': '711251',
#               'childcategories': [],
#               'childseries': [{'f': 'A',
#                                'name': 'Total Biomass Energy Consumed by the '
#                                        'Commercial Sector, Annual',
#                                'series_id': 'TOTAL.BMCCBUS.A',
#                                'units': 'Trillion Btu',
#                                'updated': '25-MAR-19 02.55.14 PM'},
#                               {'f': 'M',
#                                'name': 'Total Biomass Energy Consumed by the '
#                                        'Commercial Sector, Monthly',
#                                'series_id': 'TOTAL.BMCCBUS.M',
#                                'units': 'Trillion Btu',
#                                'updated': '24-JUN-19 11.59.37 AM'},
#                               {'f': 'A',
#                                'name': 'Coal Consumed by the Commercial '
#                                        'Sector, Annual',
#                                'series_id': 'TOTAL.CLCCBUS.A',
#                                'units': 'Trillion Btu',
#                                'updated': '25-APR-19 08.13.40 AM'},
#                               {'f': 'M',
#                                'name': 'Coal Consumed by the Commercial '
#                                        'Sector, Monthly',
#                                'series_id': 'TOTAL.CLCCBUS.M',
#                                'units': 'Trillion Btu',
#                                'updated': '24-JUN-19 11.59.37 AM'},
#                               {'f': 'A',
#                                'name': 'Electricity Retail Sales to the '
#                                        'Commercial Sector, Annual',
#                                'series_id': 'TOTAL.ESCCBUS.A',
#                                'units': 'Trillion Btu',
#                                'updated': '25-MAR-19 02.55.14 PM'},
#                               {'f': 'M',
#                                'name': 'Electricity Retail Sales to the '
#                                        'Commercial Sector, Monthly',
#                                'series_id': 'TOTAL.ESCCBUS.M',
#                                'units': 'Trillion Btu',
#                                'updated': '24-JUN-19 11.59.37 AM'},
#                               {'f': 'A',
#                                'name': 'Total Fossil Fuels Consumed by the '
#                                        'Commercial Sector, Annual',
#                                'series_id': 'TOTAL.FFCCBUS.A',
#                                'units': 'Trillion Btu',
#                                'updated': '24-JUN-19 11.59.37 AM'},
#                               {'f': 'M',
#                                'name': 'Total Fossil Fuels Consumed by the '
#                                        'Commercial Sector, Monthly',
#                                'series_id': 'TOTAL.FFCCBUS.M',
#                                'units': 'Trillion Btu',
#                                'updated': '24-JUN-19 11.59.37 AM'},
#                               {'f': 'A',
#                                'name': 'Geothermal Energy Consumed by the '
#                                        'Commercial Sector, Annual',
#                                'series_id': 'TOTAL.GECCBUS.A',
#                                'units': 'Trillion Btu',
#                                'updated': '25-APR-19 08.13.40 AM'},
#                               {'f': 'M',
#                                'name': 'Geothermal Energy Consumed by the '
#                                        'Commercial Sector, Monthly',
#                                'series_id': 'TOTAL.GECCBUS.M',
#                                'units': 'Trillion Btu',
#                                'updated': '24-JUN-19 11.59.37 AM'},
#                               {'f': 'A',
#                                'name': 'Conventional Hydroelectric Power '
#                                        'Consumed by the Commercial Sector, '
#                                        'Annual',
#                                'series_id': 'TOTAL.HVCCBUS.A',
#                                'units': 'Trillion Btu',
#                                'updated': '25-MAR-19 02.55.14 PM'},
#                               {'f': 'M',
#                                'name': 'Conventional Hydroelectric Power '
#                                        'Consumed by the Commercial Sector, '
#                                        'Monthly',
#                                'series_id': 'TOTAL.HVCCBUS.M',
#                                'units': 'Trillion Btu',
#                                'updated': '24-JUN-19 11.59.37 AM'},
#                               {'f': 'A',
#                                'name': 'Commercial Sector Electrical System '
#                                        'Energy Losses, Annual',
#                                'series_id': 'TOTAL.LOCCBUS.A',
#                                'units': 'Trillion Btu',
#                                'updated': '24-JUN-19 11.59.37 AM'},
#                               {'f': 'M',
#                                'name': 'Commercial Sector Electrical System '
#                                        'Energy Losses, Monthly',
#                                'series_id': 'TOTAL.LOCCBUS.M',
#                                'units': 'Trillion Btu',
#                                'updated': '24-JUN-19 11.59.37 AM'},
#                               {'f': 'A',
#                                'name': 'Natural Gas Consumed by the Commercial '
#                                        'Sector (Excluding Supplemental Gaseous '
#                                        'Fuels), Annual',
#                                'series_id': 'TOTAL.NNCCBUS.A',
#                                'units': 'Trillion Btu',
#                                'updated': '24-JUN-19 11.59.37 AM'},
#                               {'f': 'M',
#                                'name': 'Natural Gas Consumed by the Commercial '
#                                        'Sector (Excluding Supplemental Gaseous '
#                                        'Fuels), Monthly',
#                                'series_id': 'TOTAL.NNCCBUS.M',
#                                'units': 'Trillion Btu',
#                                'updated': '24-JUN-19 11.59.37 AM'},
#                               {'f': 'A',
#                                'name': 'Petroleum Consumed by the Commercial '
#                                        'Sector (Excluding Biofuels), Annual',
#                                'series_id': 'TOTAL.PMCCBUS.A',
#                                'units': 'Trillion Btu',
#                                'updated': '23-MAY-19 03.52.44 PM'},
#                               {'f': 'M',
#                                'name': 'Petroleum Consumed by the Commercial '
#                                        'Sector (Excluding Biofuels), Monthly',
#                                'series_id': 'TOTAL.PMCCBUS.M',
#                                'units': 'Trillion Btu',
#                                'updated': '24-JUN-19 11.59.37 AM'},
#                               {'f': 'A',
#                                'name': 'Total Renewable Energy Consumed by the '
#                                        'Commercial Sector, Annual',
#                                'series_id': 'TOTAL.RECCBUS.A',
#                                'units': 'Trillion Btu',
#                                'updated': '25-APR-19 08.13.40 AM'},
#                               {'f': 'M',
#                                'name': 'Total Renewable Energy Consumed by the '
#                                        'Commercial Sector, Monthly',
#                                'series_id': 'TOTAL.RECCBUS.M',
#                                'units': 'Trillion Btu',
#                                'updated': '24-JUN-19 11.59.37 AM'},
#                               {'f': 'A',
#                                'name': 'Solar Energy Consumed by the '
#                                        'Commercial Sector, Annual',
#                                'series_id': 'TOTAL.SOCCBUS.A',
#                                'units': 'Trillion Btu',
#                                'updated': '25-APR-19 08.13.40 AM'},
#                               {'f': 'M',
#                                'name': 'Solar Energy Consumed by the '
#                                        'Commercial Sector, Monthly',
#                                'series_id': 'TOTAL.SOCCBUS.M',
#                                'units': 'Trillion Btu',
#                                'updated': '24-JUN-19 11.59.37 AM'},
#                               {'f': 'A',
#                                'name': 'Total Energy Consumed by the '
#                                        'Commercial Sector, Annual',
#                                'series_id': 'TOTAL.TECCBUS.A',
#                                'units': 'Trillion Btu',
#                                'updated': '24-JUN-19 11.59.37 AM'},
#                               {'f': 'M',
#                                'name': 'Total Energy Consumed by the '
#                                        'Commercial Sector, Monthly',
#                                'series_id': 'TOTAL.TECCBUS.M',
#                                'units': 'Trillion Btu',
#                                'updated': '24-JUN-19 11.59.37 AM'},
#                               {'f': 'A',
#                                'name': 'Total Primary Energy Consumed by the '
#                                        'Commercial Sector, Annual',
#                                'series_id': 'TOTAL.TXCCBUS.A',
#                                'units': 'Trillion Btu',
#                                'updated': '24-JUN-19 11.59.37 AM'},
#                               {'f': 'M',
#                                'name': 'Total Primary Energy Consumed by the '
#                                        'Commercial Sector, Monthly',
#                                'series_id': 'TOTAL.TXCCBUS.M',
#                                'units': 'Trillion Btu',
#                                'updated': '24-JUN-19 11.59.37 AM'},
#                               {'f': 'A',
#                                'name': 'Wind Energy Consumed by the Commercial '
#                                        'Sector, Annual',
#                                'series_id': 'TOTAL.WYCCBUS.A',
#                                'units': 'Trillion Btu',
#                                'updated': '25-MAR-19 02.55.14 PM'},
#                               {'f': 'M',
#                                'name': 'Wind Energy Consumed by the Commercial '
#                                        'Sector, Monthly',
#                                'series_id': 'TOTAL.WYCCBUS.M',
#                                'units': 'Trillion Btu',
#                                'updated': '24-JUN-19 11.59.37 AM'}],
#               'name': 'Commercial Sector Energy Consumption',
#               'notes': '',
#               'parent_category_id': '711226'},
#  'request': {'category_id': 711251, 'command': 'category'}}

# %%
url = "http://api.eia.gov/series/?api_key="
api_code1="&series_id=TOTAL."
api_code2=".A"
category=["TECCBUS"]
         

#Total Energy Consumption= "TECCBUS"
#"BMCCBUS","CLCCBUS","ESCCBUS","FFCCBUS","GECCBUS", "HVCCBUS","LOCCBUS","NNCCBUS","PMCCBUS","RECCBUS","SOCCBUS","TXCCBUS","WYCCBUS"
#query_url=f"{url}{api_key}&series_id=TOTAL.BMCCBUS.A"
#print(query_url)

#eia_json = requests.get(query_url).json()

#pprint(eia_json)

# %%
start = []
end = []
f = []
name = []
sector = []
series_id = []
units = []
updated = []
year = []
value = []
data = []
count_cat = 0

for cat in category:
        query_url = url + api_key + api_code1 + cat + api_code2
        count_cat = count_cat + 1
        print("Processing Record " + str(count_cat) + " | " + cat)

        consumption_response = requests.get(query_url).json()
        
       
        data.append(consumption_response["series"][0]["data"])
        ln = (len(data[0]))

        for i in range(0,ln):
            start.append(consumption_response["series"][0]["start"])
            end.append(consumption_response["series"][0]["end"])
            f.append(consumption_response["series"][0]["f"])
            name.append(consumption_response["series"][0]["name"])
            sector.append(consumption_response["series"][0]["name"].split(" ")[5])
            series_id.append(consumption_response["series"][0]["series_id"])
            units.append(consumption_response["series"][0]["units"])
            updated.append(consumption_response["series"][0]["updated"])
            year.append(consumption_response["series"][0]["data"][i][0])
            value.append(consumption_response["series"][0]["data"][i][1])
print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Processing Record 1 | TECCBUS
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
consumption_comm_df = pd.DataFrame({
   "start":start,
   "end":end,
   "name": name,
   "sector": sector,
   "series_id": series_id,
   "units": units,
   "updated": updated,
   "year": year,
   "value": value
})
consumption_comm_df
# Out:
#    start   end                                               name      sector  \
# 0   1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# 1   1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# 2   1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# 3   1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# 4   1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# 5   1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# 6   1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# 7   1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# 8   1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# 9   1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# 10  1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# 11  1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# 12  1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# 13  1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# 14  1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# 15  1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# 16  1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# 17  1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# 18  1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# 19  1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# 20  1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# 21  1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# 22  1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# 23  1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# 24  1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# 25  1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# 26  1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# 27  1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# 28  1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# 29  1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# ..   ...   ...                                                ...         ...
# 40  1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# 41  1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# 42  1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# 43  1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# 44  1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# 45  1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# 46  1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# 47  1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# 48  1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# 49  1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# 50  1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# 51  1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# 52  1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# 53  1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# 54  1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# 55  1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# 56  1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# 57  1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# 58  1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# 59  1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# 60  1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# 61  1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# 62  1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# 63  1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# 64  1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# 65  1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# 66  1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# 67  1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# 68  1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
# 69  1949  2018  Total Energy Consumed by the Commercial Sector...  Commercial
#
#           series_id         units                   updated  year      value
# 0   TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  2018  18607.551
# 1   TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  2017  17899.252
# 2   TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  2016  18030.223
# 3   TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  2015  18156.728
# 4   TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  2014  18264.465
# 5   TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  2013  17929.446
# 6   TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  2012  17421.351
# 7   TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  2011  17981.378
# 8   TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  2010  18058.632
# 9   TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  2009  17887.561
# 10  TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  2008  18402.244
# 11  TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  2007  18252.918
# 12  TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  2006  17707.235
# 13  TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  2005  17853.445
# 14  TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  2004  17655.462
# 15  TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  2003  17346.089
# 16  TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  2002  17345.692
# 17  TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  2001  17136.724
# 18  TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  2000  17175.294
# 19  TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  1999  16376.239
# 20  TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  1998  15967.448
# 21  TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  1997  15681.148
# 22  TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  1996  15171.883
# 23  TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  1995  14689.889
# 24  TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  1994  14097.265
# 25  TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  1993  13816.878
# 26  TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  1992  13441.096
# 27  TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  1991  13499.980
# 28  TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  1990  13317.346
# 29  TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  1989  13196.297
# ..              ...           ...                       ...   ...        ...
# 40  TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  1978  10511.880
# 41  TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  1977  10207.599
# 42  TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  1976  10063.334
# 43  TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  1975   9492.492
# 44  TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  1974   9393.324
# 45  TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  1973   9542.957
# 46  TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  1972   9183.416
# 47  TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  1971   8720.954
# 48  TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  1970   8346.295
# 49  TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  1969   7833.219
# 50  TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  1968   7329.032
# 51  TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  1967   6899.205
# 52  TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  1966   6324.047
# 53  TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  1965   5845.423
# 54  TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  1964   5465.993
# 55  TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  1963   5250.646
# 56  TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  1962   5036.386
# 57  TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  1961   4727.663
# 58  TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  1960   4609.400
# 59  TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  1959   4372.186
# 60  TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  1958   4119.156
# 61  TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  1957   3960.787
# 62  TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  1956   4022.859
# 63  TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  1955   3895.140
# 64  TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  1954   3732.921
# 65  TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  1953   3770.982
# 66  TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  1952   3873.385
# 67  TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  1951   3873.226
# 68  TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  1950   3893.298
# 69  TOTAL.TECCBUS.A  Trillion Btu  2019-06-24T11:59:37-0400  1949   3668.816
#
# [70 rows x 9 columns]
