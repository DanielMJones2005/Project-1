# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import requests
from pprint import pprint

# Import API key
from api_keys import api_key

# %%
url = "http://api.eia.gov/series/?api_key="
api_code1 = "&series_id=EMISS.CO2-TOTV-EC-TO-"
api_code2 = ".A"

state_abb = ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA",
           "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD",
           "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ",
           "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC",
           "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"]

# %%
start = []
end = []
f = []
geo = []
state = []
name = []
sector = []
series_id = []
source = []
units = []
units_short = []
updated = []
year = []
emission = []
data = []
count_st = 0

for st in state_abb:
        query_url = url + api_key + api_code1 + st + api_code2
        count_st = count_st + 1
        print("Processing Record " + str(count_st) + " | " + st)

        emiss_response = requests.get(query_url).json()
        
       
        data.append(emiss_response["series"][0]["data"])
        ln = (len(data[0]))

        for i in range(0,ln):
            start.append(emiss_response["series"][0]["start"])
            end.append(emiss_response["series"][0]["end"])
            f.append(emiss_response["series"][0]["f"])
            geo.append(emiss_response["series"][0]["geography"])
            state.append(emiss_response["series"][0]["geography"].split("-")[1])
            name.append(emiss_response["series"][0]["name"])
            sector.append(emiss_response["series"][0]["name"].split(" ")[0])
            series_id.append(emiss_response["series"][0]["series_id"])
            source.append(emiss_response["series"][0]["source"])
            units.append(emiss_response["series"][0]["units"])
            units_short.append(emiss_response["series"][0]["unitsshort"])
            updated.append(emiss_response["series"][0]["updated"])
            year.append(emiss_response["series"][0]["data"][i][0])
            emission.append(emiss_response["series"][0]["data"][i][1])
print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Processing Record 1 | AL
# Processing Record 2 | AK
# Processing Record 3 | AZ
# Processing Record 4 | AR
# Processing Record 5 | CA
# Processing Record 6 | CO
# Processing Record 7 | CT
# Processing Record 8 | DE
# Processing Record 9 | FL
# Processing Record 10 | GA
# Processing Record 11 | HI
# Processing Record 12 | ID
# Processing Record 13 | IL
# Processing Record 14 | IN
# Processing Record 15 | IA
# Processing Record 16 | KS
# Processing Record 17 | KY
# Processing Record 18 | LA
# Processing Record 19 | ME
# Processing Record 20 | MD
# Processing Record 21 | MA
# Processing Record 22 | MI
# Processing Record 23 | MN
# Processing Record 24 | MS
# Processing Record 25 | MO
# Processing Record 26 | MT
# Processing Record 27 | NE
# Processing Record 28 | NV
# Processing Record 29 | NH
# Processing Record 30 | NJ
# Processing Record 31 | NM
# Processing Record 32 | NY
# Processing Record 33 | NC
# Processing Record 34 | ND
# Processing Record 35 | OH
# Processing Record 36 | OK
# Processing Record 37 | OR
# Processing Record 38 | PA
# Processing Record 39 | RI
# Processing Record 40 | SC
# Processing Record 41 | SD
# Processing Record 42 | TN
# Processing Record 43 | TX
# Processing Record 44 | UT
# Processing Record 45 | VT
# Processing Record 46 | VA
# Processing Record 47 | WA
# Processing Record 48 | WV
# Processing Record 49 | WI
# Processing Record 50 | WY
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# create dataframe
emiss_elect_df = pd.DataFrame({
   "start":start,
   "end":end,
   "geo": geo,
   "state": state,
   "name": name,
   "sector": sector,
   "series_id": series_id,
   "source": source,
   "units": units,
   "units_short": units_short,
   "updated": updated,
   "year": year,
   "emission": emission
})

emiss_elect_df['year'] = emiss_elect_df['year'].astype(int)
emiss_elect_df
# Out:
#      start   end     geo state  \
# 0     1980  2016  USA-AL    AL
# 1     1980  2016  USA-AL    AL
# 2     1980  2016  USA-AL    AL
# 3     1980  2016  USA-AL    AL
# 4     1980  2016  USA-AL    AL
# 5     1980  2016  USA-AL    AL
# 6     1980  2016  USA-AL    AL
# 7     1980  2016  USA-AL    AL
# 8     1980  2016  USA-AL    AL
million metric tons CO2     mmt CO2  2018-12-12T09:19:26-0500  2006
# 1824  million metric tons CO2     mmt CO2  2018-12-12T09:19:26-0500  2005
# 1825  million metric tons CO2     mmt CO2  2018-12-12T09:19:26-0500  2004
# 1826  million metric tons CO2     mmt CO2  2018-12-12T09:19:26-0500  2003
# 1827  million metric tons CO2     mmt CO2  2018-12-12T09:19:26-0500  2002
# 1828  million metric tons CO2     mmt CO2  2018-12-12T09:19:26-0500  2001
# 1829  million metric tons CO2     mmt CO2  2018-12-12T09:19:26-0500  2000
# 1830  million metric tons CO2     mmt CO2  2018-12-12T09:19:26-0500  1999
# 1831  million metric tons CO2     mmt CO2  2018-12-12T09:19:26-0500  1998
# 1832  million metric tons CO2     mmt CO2  2018-12-12T09:19:26-0500  1997
# 1833  million metric tons CO2     mmt CO2  2018-12-12T09:19:26-0500  1996
# 1834  million metric tons CO2     mmt CO2  2018-12-12T09:19:26-0500  1995
# 1835  million metric tons CO2     mmt CO2  2018-12-12T09:19:26-0500  1994
# 1836  million metric tons CO2     mmt CO2  2018-12-12T09:19:26-0500  1993
# 1837  million metric tons CO2     mmt CO2  2018-12-12T09:19:26-0500  1992
# 1838  million metric tons CO2     mmt CO2  2018-12-12T09:19:26-0500  1991
# 1839  million metric tons CO2     mmt CO2  2018-12-12T09:19:26-0500  1990
# 1840  million metric tons CO2     mmt CO2  2018-12-12T09:19:26-0500  1989
# 1841  million metric tons CO2     mmt CO2  2018-12-12T09:19:26-0500  1988
# 1842  million metric tons CO2     mmt CO2  2018-12-12T09:19:26-0500  1987
# 1843  million metric tons CO2     mmt CO2  2018-12-12T09:19:26-0500  1986
# 1844  million metric tons CO2     mmt CO2  2018-12-12T09:19:26-0500  1985
# 1845  million metric tons CO2     mmt CO2  2018-12-12T09:19:26-0500  1984
# 1846  million metric tons CO2     mmt CO2  2018-12-12T09:19:26-0500  1983
# 1847  million metric tons CO2     mmt CO2  2018-12-12T09:19:26-0500  1982
# 1848  million metric tons CO2     mmt CO2  2018-12-12T09:19:26-0500  1981
# 1849  million metric tons CO2     mmt CO2  2018-12-12T09:19:26-0500  1980
#
#        emission
# 0     55.245430
# 1     61.932375
# 2     65.062592
# 3     64.219449
# 4     66.461873
# 5     73.964577
# 6     76.711690
# 7     66.379386
# 8     81.024076
# 9     85.901615
# 10    83.630331
# 11    81.340110
# 12    77.619330
# 13    78.159465
# 14    77.390412
# 15    73.911306
# 16    76.746379
# 17    71.810333
# 18    70.618160
# 19    68.616088
# 20    70.348491
# 21    65.121050
# 22    59.555341
# 23    63.577327
# 24    57.592803
# 25    54.804468
# 26    50.887225
# 27    50.554197
# 28    46.015139
# 29    47.793150
# ...         ...
# 1820  41.922840
# 1821  43.999048
# 1822  43.526719
# 1823  43.050186
# 1824  43.327883
# 1825  44.103458
# 1826  43.605531
# 1827  42.501296
# 1828  44.012539
# 1829  44.033171
# 1830  42.699538
# 1831  44.482559
# 1832  40.048184
# 1833  40.353670
# 1834  39.553377
# 1835  42.085293
# 1836  40.055473
# 1837  41.929217
# 1838  38.283839
# 1839  39.217969
# 1840  36.702685
# 1841  38.897776
# 1842  37.043150
# 1843  28.620404
# 1844  34.928647
# 1845  30.617916
# 1846  26.466957
# 1847  28.602896
# 1848  26.957486
# 1849  22.323626
#
# [1850 rows x 13 columns]

# %%
emiss_10years = emiss_elect_df.set_index("state","sector").groupby(["state","sector"])

tot_10emissions = emiss_elect_df[emiss_elect_df["year"] >= 2006].groupby(["state","sector"])["emission"].sum()

rec10yrs_df = pd.DataFrame({"Total Emissions": tot_10emissions})

rec10yrs_df
# Out:
#                 Total Emissions
# state sector
# AK    Electric        33.760007
# AL    Electric       780.533394
# AR    Electric       343.127933
# AZ    Electric       577.674893
# CA    Electric       495.880605
# CO    Electric       429.647746
# CT    Electric        82.174986
# DE    Electric        49.569771
# FL    Electric      1239.616985
# GA    Electric       765.256594
# HI    Electric        80.467075
# IA    Electric       382.525175
# ID    Electric         9.464018
# IL    Electric       966.048562
# IN    Electric      1170.312821
# KS    Electric       359.476572
# KY    Electric       967.377173
# LA    Electric       440.324000
# MA    Electric       172.968261
# MD    Electric       247.927407
# ME    Electric        22.824878
# MI    Electric       726.333474
# MN    Electric       323.794536
# MO    Electric       803.653922
# MS    Electric       270.121804
# MT    Electric       194.296120
# NC    Electric       692.781993
# ND    Electric       326.591825
# NE    Electric       254.152279
# NH    Electric        52.452973
# NJ    Electric       187.818592
# NM    Electric       315.901463
# NV    Electric       175.133645
# NY    Electric       395.740455
# OH    Electric      1188.769879
# OK    Electric       505.254759
# OR    Electric        91.318563
# PA    Electric      1199.912923
# RI    Electric        31.342708
# SC    Electric       390.805513
# SD    Electric        33.953506
# TN    Electric       467.417118
# TX    Electric      2452.433639
# UT    Electric       378.455705
# VA    Electric       361.230826
# VT    Electric         0.052806
# WA    Electric       117.080321
# WI    Electric       455.374764
# WV    Electric       812.678739
# WY    Electric       472.820144
