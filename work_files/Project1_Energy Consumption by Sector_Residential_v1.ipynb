# %%
#Project 1: EIA Data Sets > Total Energy > Energy Consumption by Sector > Energy Consumption by Sector

# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from tqdm import tqdm_notebook
from datetime import datetime
from pprint import pprint

# Import API key
from api_keys_res import api_key

# %%
#http://api.eia.gov/series/?api_key=YOUR_API_KEY_HERE&series_id=TOTAL.TERCBUS.A

url = "http://api.eia.gov/series/?api_key="
api_code1 = "&series_id=TOTAL."
api_energy_source = "TERCBUS"
api_period = ".A"

# %%
start = []
end = []
f = []
name = []
sector = []
sec = "Residental"
source = []
energy_source = "Total Energy"
series_id = []
units = []
updated = []
year = []
value = []
count_st = 0

query_url = url + api_key + api_code1 + api_energy_source + api_period
consume_res_resp = requests.get(query_url).json()
     
data = []
data.append(consume_res_resp["series"][0]["data"])
ln = (len(data[0]))

for i in range(0, ln):

    start.append(consume_res_resp["series"][0]["start"])
    end.append(consume_res_resp["series"][0]["end"])
    f.append(consume_res_resp["series"][0]["f"])
    name.append(consume_res_resp["series"][0]["name"])
    source.append(energy_source)
    sector.append(sec)
    series_id.append(consume_res_resp["series"][0]["series_id"])
    units.append(consume_res_resp["series"][0]["units"])
    updated.append(consume_res_resp["series"][0]["updated"])
    year.append(consume_res_resp["series"][0]["data"][i][0])
    value.append(consume_res_resp["series"][0]["data"][i][1])
        
print("-----------------------------")
print("Data Retrieval Complete")      
print("-----------------------------")
# Out:
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Create DataFrame
energy_consume_resi_df = pd.DataFrame({
    "start": start,
    "end": end,
    "f": f,
    "name": name,
    "source": source,
    "sector": sector,
    "series_id": series_id,
    "units": units,
    "updated": updated,
    "year": year,
    "value": value
    
})

# %%
energy_consume_resi_df
# Out:
#    start   end  f                                               name  \
# 0   1949  2018  A  Total Energy Consumed by the Residential Secto...
# 1   1949  2018  A  Total Energy Consumed by the Residential Secto...
# 2   1949  2018  A  Total Energy Consumed by the Residential Secto...
# 3   1949  2018  A  Total Energy Consumed by the Residential Secto...
# 4   1949  2018  A  Total Energy Consumed by the Residential Secto...
# 5   1949  2018  A  Total Energy Consumed by the Residential Secto...
# 6   1949  2018  A  Total Energy Consumed by the Residential Secto...
# 7   1949  2018  A  Total Energy Consumed by the Residential Secto...
# 8   1949  2018  A  Total Energy Consumed by the Residential Secto...
# 9   1949  2018  A  Total Energy Consumed by the Residential Secto...
# 10  1949  2018  A  Total Energy Consumed by the Residential Secto...
# 11  1949  2018  A  Total Energy Consumed by the Residential Secto...
# 12  1949  2018  A  Total Energy Consumed by the Residential Secto...
# 13  1949  2018  A  Total Energy Consumed by the Residential Secto...
# 14  1949  2018  A  Total Energy Consumed by the Residential Secto...
# 15  1949  2018  A  Total Energy Consumed by the Residential Secto...
# 16  1949  2018  A  Total Energy Consumed by the Residential Secto...
# 17  1949  2018  A  Total Energy Consumed by the Residential Secto...
# 18  1949  2018  A  Total Energy Consumed by the Residential Secto...
# 19  1949  2018  A  Total Energy Consumed by the Residential Secto...
# 20  1949  2018  A  Total Energy Consumed by the Residential Secto...
# 21  1949  2018  A  Total Energy Consumed by the Residential Secto...
# 22  1949  2018  A  Total Energy Consumed by the Residential Secto...
# 23  1949  2018  A  Total Energy Consumed by the Residential Secto...
# 24  1949  2018  A  Total Energy Consumed by the Residential Secto...
# 25  1949  2018  A  Total Energy Consumed by the Residential Secto...
# 26  1949  2018  A  Total Energy Consumed by the Residential Secto...
# 27  1949  2018  A  Total Energy Consumed by the Residential Secto...
# 28  1949  2018  A  Total Energy Consumed by the Residential Secto...
# 29  1949  2018  A  Total Energy Consumed by the Residential Secto...
# ..   ...   ... ..                                                ...
# 40  1949  2018  A  Total Energy Consumed by the Residential Secto...
# 41  1949  2018  A  Total Energy Consumed by the Residential Secto...
# 42  1949  2018  A  Total Energy Consumed by the Residential Secto...
# 43  1949  2018  A  Total Energy Consumed by the Residential Secto...
# 44  1949  2018  A  Total Energy Consumed by the Residential Secto...
# 45  1949  2018  A  Total Energy Consumed by the Residential Secto...
# 46  1949  2018  A  Total Energy Consumed by the Residential Secto...
# 47  1949  2018  A  Total Energy Consumed by the Residential Secto...
# 48  1949  2018  A  Total Energy Consumed by the Residential Secto...
# 49  1949  2018  A  Total Energy Consumed by the Residential Secto...
# 50  1949  2018  A  Total Energy Consumed by the Residential Secto...
# 51  1949  2018  A  Total Energy Consumed by the Residential Secto...
# 52  1949  2018  A  Total Energy Consumed by the Residential Secto...
# 53  1949  2018  A  Total Energy Consumed by the Residential Secto...
# 54  1949  2018  A  Total Energy Consumed by the Residential Secto...
# 55  1949  2018  A  Total Energy Consumed by the Residential Secto...
# 56  1949  2018  A  Total Energy Consumed by the Residential Secto...
# 57  1949  2018  A  Total Energy Consumed by the Residential Secto...
# 58  1949  2018  A  Total Energy Consumed by the Residential Secto...
# 59  1949  2018  A  Total Energy Consumed by the Residential Secto...
# 60  1949  2018  A  Total Energy Consumed by the Residential Secto...
# 61  1949  2018  A  Total Energy Consumed by the Residential Secto...
# 62  1949  2018  A  Total Energy Consumed by the Residential Secto...
# 63  1949  2018  A  Total Energy Consumed by the Residential Secto...
# 64  1949  2018  A  Total Energy Consumed by the Residential Secto...
#